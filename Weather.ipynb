# %% [markdown]
# # Weather based IF statement
#
# ## What should i include?
# The statements and variables i must use will be:
# - IF statement
# - Weather variable
# - Temperature
# - elif statement
# - greater than > and lower than <

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#What should i wear today?

weather = "sunny"
temperature = 14

if temperature < 15:
    print("Wear a jacket")
if temperature < 15 and weather == "sunny":
    print("it may be sunny but it could still be chilly")
# Out:
# Wear a jacket
# it may be sunny but it could still be chilly
